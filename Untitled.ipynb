# %%
from elasticsearch import Elasticsearch, RequestsHttpConnection, helpers

# %%
import csv

# %%
class ElasticConnection:
    def __init__(self):
        self.user = 'elastic'
        self.password = 'changeme'
        self.index = "saio-10"
        self.elastic_client = Elasticsearch(
            host='192.168.1.124',
            http_auth=(self.user, self.password),
            scheme="http",
            port=9200,
            connection_class=RequestsHttpConnection
        )

# %%
elastic_client = ElasticConnection()

# %%
body = {
            "query": {
                "bool": {
                    "must_not": {
                        "match": {
                            "programname": {
                                "query": "kernel rsyslogd",
                                "operator": "or"
                            }
                            # "severity": "info"
                        }
                    }
                }
            }
        }

# %%
records = elastic_client.elastic_client.search(index=elastic_client.index, body=body)
# Out:
# /home/ghavipour/PycharmProjects/LogDB/venv/lib/python3.8/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.13/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)

# %%
records
# Out:
# {'took': 7311,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 0.0,
#   'hits': [{'_index': 'saio-10',
#     '_type': '_doc',
#     '_id': 'oeRHaXwBc0tCP-eNcDua',
#     '_score': 0.0,
#     '_source': {'type': 'rsyslog',
#      'host': '172.19.0.1',
#      '@timestamp': '2021-10-10T08:17:41.932Z',
#      'sysloghost': 'minoo-VirtualBox',
#      'programname': 'container-server',
#      'facility': 'local3',
#      '@version': '1',
#      'procid': '-',
#      'port': 43520,
#      'severity': 'err',
#      'message': ' STDERR: 127.0.0.1 - - [10/Oct/2021 08:17:41] "REPLICATE /sdb2/122/1e9b083f80cdf8a497530ceecd51e4a9 HTTP/1.1" 200 725 0.004941'}},
#    {'_index': 'saio-10',
#     '_type': '_doc',
#     '_id': 'ouRHaXwBc0tCP-eNcDue',
#     '_score': 0.0,
#     '_source': {'type': 'rsyslog',
#      'host': '172.19.0.1',
#      '@timestamp': '2021-10-10T08:17:41.916Z',
#      'sysloghost': 'minoo-VirtualBox',
#      'programname': 'container-server',
#      'facility': 'local3',
#      '@version': '1',
#      'procid': '-',
#      'port': 43520,
#      'severity': 'err',
#      'message': ' STDERR: 127.0.0.1 - - [10/Oct/2021 08:17:41] "REPLICATE /sdb2/559/8bcae2d8a5adc5837a87336e2ad064c2 HTTP/1.1" 200 724 0.006700'}},
#    {'_index': 'saio-10',
#     '_type': '_doc',
#     '_id': 'o-RHaXwBc0tCP-eNcDug',
#     '_score': 0.0,
#     '_source': {'type': 'rsyslog',
#      'host': '172.19.0.1',
#      '@timestamp': '2021-10-10T08:17:41.909Z',
#      'sysloghost': 'minoo-VirtualBox',
#      'programname': 'container-server',
#      'facility': 'local3',
#      '@version': '1',
#      'procid': '-',
#      'port': 43520,
#      'severity': 'err',
#      'message': ' STDERR: 127.0.0.1 - - [10/Oct/2021 08:17:41] "REPLICATE /sdb2/84/15395d20d653411b73b8b083b5512054 HTTP/1.1" 200 725 1.513661'}},
#    {'_index': 'saio-10',
#     '_type': '_doc',
#     '_id': 'pORHaXwBc0tCP-eNcDug',
#     '_score': 0.0,
#     '_source': {'type': 'rsyslog',
#      'host': '172.19.0.1',
#      '@timestamp': '2021-10-10T08:17:41.937Z',
#      'sysloghost': 'minoo-VirtualBox',
#      'programname': 'container-server',
#      'facility': 'local3',
#      '@version': '1',
#      'procid': '-',
#      'port': 43520,
#      'severity': 'err',
#      'message': ' STDERR: 127.0.0.1 - - [10/Oct/2021 08:17:41] "REPLICATE /sdb2/380/5f1803839f6d476821b03186519f50e3 HTTP/1.1" 200 725 0.003905'}},
#    {'_index': 'saio-10',
#     '_type': '_doc',
#     '_id': 'peRHaXwBc0tCP-eNcjui',
#     '_score': 0.0,
#     '_source': {'type': 'rsyslog',
#      'host': '172.19.0.1',
#      '@timestamp': '2021-10-10T08:17:42.153Z',
#      'sysloghost': 'minoo-VirtualBox',
#      'programname': 'container-replicator',
#      'facility': 'local0',
#      '@version': '1',
#      'procid': '-',
#      'port': 43520,
#      'tags': ['swift', 'CONT_REP_FINISH'],
#      'severity': 'info',
#      'message': ' Replication run OVER'}},
#    {'_index': 'saio-10',
#     '_type': '_doc',
#     '_id': 'puRHaXwBc0tCP-eNcjui',
#     '_score': 0.0,
#     '_source': {'ReplicationDBsBytePerSecond': 0.82129,
#      'type': 'rsyslog',
#      'host': '172.19.0.1',
#      '@timestamp': '2021-10-10T08:17:42.154Z',
#      'sysloghost': 'minoo-VirtualBox',
#      'programname': 'container-replicator',
#      'facility': 'local0',
#      '@version': '1',
#      'procid': '-',
#      'ReplicatorNumDBs': 9,
#      'ReplicationDBsSeconds': 10.95839,
#      'port': 43520,
#      'tags': ['swift', 'CONT_REP_ATTEMPTED'],
#      'severity': 'info',
#      'message': ' Attempted to replicate 9 dbs in 10.95839 seconds (0.82129/s)'}},
#    {'_index': 'saio-10',
#     '_type': '_doc',
#     '_id': 'p-RHaXwBc0tCP-eNcjui',
#     '_score': 0.0,
#     '_source': {'type': 'rsyslog',
#      'host': '172.19.0.1',
#      '@timestamp': '2021-10-10T08:17:42.154Z',
#      'sysloghost': 'minoo-VirtualBox',
#      'programname': 'container-replicator',
#      'facility': 'local0',
#      'ReplicatorRemovedDBs': '0',
#      '@version': '1',
#      'procid': '-',
#      'port': 43520,
#      'tags': ['swift', 'CONT_REP_REMOVED'],
#      'severity': 'info',
#      'message': ' Removed 0 dbs'}},
#    {'_index': 'saio-10',
#     '_type': '_doc',
#     '_id': 'qORHaXwBc0tCP-eNcjui',
#     '_score': 0.0,
#     '_source': {'ReplicationEmpty': '0',
#      'ReplicationRemoteMerge': '0',
#      'type': 'rsyslog',
#      'ReplicationRsync': '0',
#      'ReplicationTS': '0',
#      'ReplicationHashMatch': '0',
#      'host': '172.19.0.1',
#      '@timestamp': '2021-10-10T08:17:42.247Z',
#      'sysloghost': 'minoo-VirtualBox',
#      'programname': 'container-replicator',
#      'ReplicationDiffCap': '0',
#      'ReplicationNoChange': '18',
#      'facility': 'local0',
#      '@version': '1',
#      'procid': '-',
#      'port': 43520,
#      'tags': ['swift', 'CONT_REP_CHANGE'],
#      'severity': 'info',
#      'message': ' diff:0 diff_capped:0 empty:0 hashmatch:0 no_change:18 remote_merge:0 rsync:0 ts_repl:0',
#      'ReplicationDiff': '0'}},
#    {'_index': 'saio-10',
#     '_type': '_doc',
#     '_id': 'qeRHaXwBc0tCP-eNcjui',
#     '_score': 0.0,
#     '_source': {'type': 'rsyslog',
#      'ReplicationFail': 0,
#      'host': '172.19.0.1',
#      '@timestamp': '2021-10-10T08:17:42.154Z',
#      'sysloghost': 'minoo-VirtualBox',
#      'programname': 'container-replicator',
#      'facility': 'local0',
#      'ReplicationSuccess': 18,
#      '@version': '1',
#      'procid': '-',
#      'port': 43520,
#      'tags': ['swift', 'CONT_REP_RATE'],
#      'severity': 'info',
#      'message': ' 18 successes, 0 failures'}},
#    {'_index': 'saio-10',
#     '_type': '_doc',
#     '_id': 'quRHaXwBc0tCP-eNdDti',
#     '_score': 0.0,
#     '_source': {'type': 'rsyslog',
#      'status_int': '201',
#      'host': '172.19.0.1',
#      '@timestamp': '2021-10-10T08:17:42.703Z',
#      'sysloghost': 'minoo-VirtualBox',
#      'programname': 'container-server',
#      'device_name': 'sdb11',
#      'container_path': 'Mycontainer30',
#      'facility': 'local0',
#      'referer': 'PUT http://localhost:8080/v1/AUTH_test/Mycontainer30',
#      'datetime': '10/Oct/2021:08:17:42',
#      '@version': '1',
#      'remote_addr': '127.0.0.1',
#      'server_pid': 12676,
#      'port': 43520,
#      'tags': ['swift', 'CONT_SER_TRANSACTION'],
#      'severity': 'info',
#      'message': ' 127.0.0.1 - - [10/Oct/2021:08:17:42 +0000] "PUT /sdb11/132/AUTH_test/Mycontainer30" 201 - "PUT http://localhost:8080/v1/AUTH_test/Mycontainer30" "tx0c1e08db3f9f4e0083de4-006162a1a1" "proxy-server 12716" 2.2059 "-" 12676 0',
#      'partition_number': '132',
#      'account_path': 'AUTH_test',
#      'request_method': 'PUT',
#      'user_agent': 'proxy-server 12716',
#      'policy_index': 0,
#      'request_time': 2.2059,
#      'procid': '-',
#      'request_path': '/sdb11/132/AUTH_test/Mycontainer30',
#      'transaction_id': 'tx0c1e08db3f9f4e0083de4-006162a1a1'}}]}}
